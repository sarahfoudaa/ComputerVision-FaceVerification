# %%
https://github.com/serengil/deepface

# %%
# !pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 33.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 11.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 10.6 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116934 sha256=827fcfc3bfe5a9c06bbcf1c4f84b2b07a87e898d188ee525980c523d3eeec257
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# ...

# %%
import matplotlib.pyplot as plt

# %%
img1 = plt.imread("/content/Johnny2.jpg")
plt.imshow(img1)

# %%
img1 = plt.imread("/content/Johnny1.jpg")
plt.imshow(img1)

# %% [markdown]
# #Face Verification

# %%
from deepface import DeepFace
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
result = DeepFace.verify(img1_path = "/content/Johnny1.jpg", img2_path = "/content/Johnny2.jpg",model_name='Facenet512')

# %%
result = DeepFace.verify(img1_path = "/content/Johnny1.jpg", img2_path = "/content/Johnny2.jpg",model_name='VGG-Face')
# Out:
# vgg_face_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: /root/.deepface/weights/vgg_face_weights.h5
# 100%|██████████| 580M/580M [00:10<00:00, 53.6MB/s]

# %%
result
# Out:
# {'verified': True,
#  'distance': 0.38823247300667785,
#  'threshold': 0.4,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 50, 'y': 173, 'w': 267, 'h': 267},
#   'img2': {'x': 434, 'y': 220, 'w': 392, 'h': 392}},
#  'time': 24.84}

# %% [markdown]
# #Face recognition

# %%
df = DeepFace.find()

# %%
#                           johnny deep1                   (johnny deep2 , anjelena joly , jenipher anistom)
df = DeepFace.find(img_path = "/content/Johnny1.jpg", db_path = "/content/rec/")
# Out:
# WARNING: Representations for images in /content/rec/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# find function lasts  4.311374664306641  seconds

# %%
df
# Out:
# [Empty DataFrame
#  Columns: [identity, source_x, source_y, source_w, source_h, VGG-Face_cosine]
#  Index: [],
#  Empty DataFrame
#  Columns: [identity, source_x, source_y, source_w, source_h, VGG-Face_cosine]
#  Index: [],
#                     identity  source_x  source_y  source_w  source_h  \
#  0  /content/rec/Johnny2.jpg        50       173       267       267
#
#     VGG-Face_cosine
#  0         0.388232  ]

# %%
#                                      johnny deep1    (johnny deep2,johnny deep3 , anjelena joly , jenipher anistom)
results = DeepFace.find(img_path = "/content/Johnny1.jpg", db_path = "/content/rec")
# Out:
# Finding representations: 100%|██████████| 4/4 [00:06<00:00,  1.56s/it]
# Representations stored in /content/rec/representations_vgg_face.pkl file.Please delete this file when you add new identities in your database.
# find function lasts  8.4331533908844  seconds

# %%
results
# Out:
# [Empty DataFrame
#  Columns: [identity, source_x, source_y, source_w, source_h, VGG-Face_cosine]
#  Index: [],
#  Empty DataFrame
#  Columns: [identity, source_x, source_y, source_w, source_h, VGG-Face_cosine]
#  Index: [],
#                     identity  source_x  source_y  source_w  source_h  \
#  0  /content/rec/Johnny3.jpg        50       173       267       267
#  1  /content/rec/Johnny2.jpg        50       173       267       267
#
#     VGG-Face_cosine
#  0         0.328278
#  1         0.388232  ]

# %%
results
# Out:
# [Empty DataFrame
#  Columns: [identity, source_x, source_y, source_w, source_h, VGG-Face_cosine]
#  Index: [],
#  Empty DataFrame
#  Columns: [identity, source_x, source_y, source_w, source_h, VGG-Face_cosine]
#  Index: [],
#                     identity  source_x  source_y  source_w  source_h  \
#  0  /content/rec/Johnny2.jpg        50       173       267       267
#
#     VGG-Face_cosine
#  0         0.388232  ]

# %% [markdown]
# #Facial Attribute Analysis

# %%
objs = DeepFace.analyze(img_path = "/content/Johnny1.jpg",
        actions = ['age', 'gender', 'race', 'emotion']
)
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 24.3MB/s]
# age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
# 100%|██████████| 539M/539M [00:10<00:00, 49.8MB/s]
# gender_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: /root/.deepface/weights/gender_model_weights.h5
# 100%|██████████| 537M/537M [00:10<00:00, 51.7MB/s]
# race_model_single_batch.h5 will be downloaded...
# Downloading...
# ...

# %%
objs
# Out:
# [{'age': 27,
#   'region': {'x': 382, 'y': 57, 'w': 61, 'h': 61},
#   'gender': {'Woman': 40.47704041004181, 'Man': 59.52296257019043},
#   'dominant_gender': 'Man',
#   'race': {'asian': 9.217610759592697,
#    'indian': 5.338227694524985,
#    'black': 1.4286347585102772,
#    'white': 53.117153234312134,
#    'middle eastern': 9.47733205421758,
#    'latino hispanic': 21.421044851603796},
#   'dominant_race': 'white',
#   'emotion': {'angry': 0.07308903150260448,
#    'disgust': 4.210390716630208e-12,
#    'fear': 22.334034740924835,
#    'happy': 4.406588232086506e-05,
#    'sad': 27.85545289516449,
#    'surprise': 4.707764844624762e-05,
#    'neutral': 49.73733723163605},
#   'dominant_emotion': 'neutral'},
#  {'age': 27,
#   'region': {'x': 295, 'y': 145, 'w': 131, 'h': 131},
#   'gender': {'Woman': 8.362720161676407, 'Man': 91.63728356361389},
#   'dominant_gender': 'Man',
#   'race': {'asian': 3.777967393398285,
#    'indian': 30.111536383628845,
# ...

# %%
objs[0]
# Out:
# {'age': 27,
#  'region': {'x': 382, 'y': 57, 'w': 61, 'h': 61},
#  'gender': {'Woman': 40.47704041004181, 'Man': 59.52296257019043},
#  'dominant_gender': 'Man',
#  'race': {'asian': 9.217610759592697,
#   'indian': 5.338227694524985,
#   'black': 1.4286347585102772,
#   'white': 53.117153234312134,
#   'middle eastern': 9.47733205421758,
#   'latino hispanic': 21.421044851603796},
#  'dominant_race': 'white',
#  'emotion': {'angry': 0.07308903150260448,
#   'disgust': 4.210390716630208e-12,
#   'fear': 22.334034740924835,
#   'happy': 4.406588232086506e-05,
#   'sad': 27.85545289516449,
#   'surprise': 4.707764844624762e-05,
#   'neutral': 49.73733723163605},
#  'dominant_emotion': 'neutral'}
